# %%
Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
Matplotlib.
Ans:Matplotlib is a powerful Python library used for creating static, animated, and interactive visualizations. It provides a wide range of plotting capabilities, making it a versatile tool for data analysis and visualization.   

Key reasons for using Matplotlib:

Versatility: It supports a wide range of plot types, from simple line plots to complex 3D visualizations.
Customization: You can customize every aspect of your plots, including colors, labels, styles, and annotations.
Integration: It integrates well with other scientific Python libraries like NumPy and Pandas.
Community and Support: A large and active community provides extensive documentation, tutorials, and support.

           
Five common plot types using the Pyplot module:

Line plots: Visualize the relationship between two variables.
Scatter plots: Show the distribution of data points in two dimensions.
Bar plots: Represent categorical data as bars.
Histograms: Display the distribution of a single variable.
Pie charts: Show the relative proportions of different categories within a whole.

# %%
Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
plot a scatter plot.
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
Note: Also add title, xlabel, and ylabel to the plot.

Ans:Scatter plots are used to visualize the relationship between two variables. Each data point is represented by a dot on the plot, where the x-coordinate corresponds to one variable and the y-coordinate corresponds to the other. This allows you to see if there's a correlation or pattern between the two variables.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.scatter(x, y)
plt.title("Scatter Plot Example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
Use the following data:
import numpy as np
For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

Ans:The subplot() function in Matplotlib is used to create multiple plots within a single figure. This allows you to compare different datasets or visualize different aspects of the same data in a more efficient and organized way.

# %%
import numpy as np
import matplotlib.pyplot as plt


x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])


x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])


x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])


x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])


plt.figure(figsize=(10, 8))


plt.subplot(2, 2, 1)
plt.plot(x1, y1, label='Line 1')
plt.title('Line Plot 1')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()


plt.subplot(2, 2, 2)
plt.plot(x2, y2, label='Line 2')
plt.title('Line Plot 2')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(x3, y3, label='Line 3')
plt.title('Line Plot 3')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(x4, y4, label='Line 4')
plt.title('Line Plot 4')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.tight_layout()
plt.show()

# %%
Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

Ans:Bar plots are used to represent categorical data as bars. The length or height of each bar corresponds to the value of the category it represents. They are effective for comparing values across different categories.

# %%
import numpy as np
import matplotlib.pyplot as plt

company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])


plt.figure(figsize=(8, 5))
plt.bar(company, profit, color='blue')
plt.title('Company Profit')
plt.xlabel('Company')
plt.ylabel('Profit')
plt.show()


plt.figure(figsize=(8, 5))
plt.barh(company, profit, color='orange')
plt.title('Company Profit (Horizontal)')
plt.xlabel('Profit')
plt.ylabel('Company')
plt.show()

# %%
Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

Ans:Box plots (also known as box and whisker plots) are used to visualize the distribution of a dataset. They provide a summary of the data, showing the median, quartiles, and potential outliers.
